# %% [markdown]
# <a href="https://colab.research.google.com/github/kamala999/Python-test-code/blob/main/Day17_Pandas_Python_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
test = pd.read_csv("/content/sample_data/california_housing_test.csv")
test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
coustmdata = pd.read_csv("/customers-100.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
coustmdata = pd.read_csv("/customers-100.csv", sep = ",")
custmdata = coustmdata

# %%
custmdata
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
health = pd.read_excel("/Healthcare-Insurance-Sample-Data.xlsx")

# %%
health
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN          Excel Sample Data        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN        NaN
# 2          NaN  Healthcare Insurance Data        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN        NaN
# 4          NaN                       Name        Age     Gender        BMI
# 5          NaN                 John Smith         35       Male       29.5
# 6          NaN              Emily Johnson         42     Female       26.8
# 7          NaN           Michael Williams         50       Male       31.2
# 8          NaN                Sarah Brown         28     Female       22.3
# 9          NaN                David Jones         39       Male       28.1
# 10         NaN          Jennifer Martinez         45     Female       29.9
# ...

# %%
health = pd.read_excel("/Healthcare-Insurance-Sample-Data1.xlsx", sheet_name = 'house')

# %%
health
# Out:
# Empty DataFrame
# Columns: [this is my house]
# Index: []

# %%
df = health = pd.read_excel("/Healthcare-Insurance-Sample-Data1.xlsx")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    51
# Unnamed: 1     2
# Unnamed: 2     4
# Unnamed: 3     4
# Unnamed: 4     4
# Unnamed: 5     4
# Unnamed: 6     4
# Unnamed: 7     4
# Unnamed: 8     4
# dtype: int64

# %%
df.dropna(inplace = True) # inplace is modifying the original dataframe work

# %%
df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8]
# Index: []

# %%
health
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8]
# Index: []

# %%
df1 = pd.read_excel("/Healthcare-Insurance-Sample-Data2.xlsx")
df1
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN          Excel Sample Data        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN        NaN
# 2          NaN  Healthcare Insurance Data        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN        NaN
# 4          NaN                       Name        Age     Gender        BMI
# 5          NaN                 John Smith         35       Male       29.5
# 6          NaN              Emily Johnson         42     Female       26.8
# 7          NaN           Michael Williams         50       Male       31.2
# 8          NaN                Sarah Brown         28     Female       22.3
# 9          NaN                David Jones         39       Male       28.1
# 10         NaN          Jennifer Martinez         45     Female       29.9
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    51
# Unnamed: 1     2
# Unnamed: 2     4
# Unnamed: 3     4
# Unnamed: 4     4
# Unnamed: 5     4
# Unnamed: 6     4
# Unnamed: 7     4
# Unnamed: 8     4
# dtype: int64

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8]
# Index: []

# %%
df1
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN          Excel Sample Data        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN        NaN
# 2          NaN  Healthcare Insurance Data        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN        NaN
# 4          NaN                       Name        Age     Gender        BMI
# 5          NaN                 John Smith         35       Male       29.5
# 6          NaN              Emily Johnson         42     Female       26.8
# 7          NaN           Michael Williams         50       Male       31.2
# 8          NaN                Sarah Brown         28     Female       22.3
# 9          NaN                David Jones         39       Male       28.1
# 10         NaN          Jennifer Martinez         45     Female       29.9
# ...

# %%
df1.dropna(inplace = True)
df1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8]
# Index: []

# %%
health1 = pd.read_excel("/content/Healthcare-Insurance-Sample-Data3.xlsx", sheet_name = 'house')

# %%
health1
# Out:
#                      Name  Age  Gender   BMI  Children Smoking Status  \
# 0              John Smith   35    Male  29.5         2     Non-Smoker
# 1           Emily Johnson   42  Female  26.8         2     Non-Smoker
# 2        Michael Williams   50    Male  31.2         3         Smoker
# 3             Sarah Brown   28  Female  22.3         1     Non-Smoker
# 4             David Jones   39    Male  28.1         2     Non-Smoker
# 5       Jennifer Martinez   45  Female  29.9         3     Non-Smoker
# 6         Daniel Anderson   33    Male  25.5         1     Non-Smoker
# 7          Jessica Wilson   37  Female  27.4         2         Smoker
# 8          Matthew Taylor   47    Male  33.0         3     Non-Smoker
# 9             Emma Garcia   31  Female  24.7         0     Non-Smoker
# 10  Christopher Rodriguez   40    Male  30.5         2     Non-Smoker
# 11       Olivia Hernandez   29  Female  23.9         1     Non-Smoker
# ...

# %%
#creating columns
health1['avarage'] = (health1['Age']+health1['Insurance Price (USD)'])/2

# %%
health1
# Out:
#                      Name  Age  Gender   BMI  Children Smoking Status  \
# 0              John Smith   35    Male  29.5         2     Non-Smoker
# 1           Emily Johnson   42  Female  26.8         2     Non-Smoker
# 2        Michael Williams   50    Male  31.2         3         Smoker
# 3             Sarah Brown   28  Female  22.3         1     Non-Smoker
# 4             David Jones   39    Male  28.1         2     Non-Smoker
# 5       Jennifer Martinez   45  Female  29.9         3     Non-Smoker
# 6         Daniel Anderson   33    Male  25.5         1     Non-Smoker
# 7          Jessica Wilson   37  Female  27.4         2         Smoker
# 8          Matthew Taylor   47    Male  33.0         3     Non-Smoker
# 9             Emma Garcia   31  Female  24.7         0     Non-Smoker
# 10  Christopher Rodriguez   40    Male  30.5         2     Non-Smoker
# 11       Olivia Hernandez   29  Female  23.9         1     Non-Smoker
# ...

# %%
health1.rename(columns={'avarage': 'mean'}, inplace=True) #rename columns

# %%
health1
# Out:
#                      Name  Age  Gender   BMI  Children Smoking Status  \
# 0              John Smith   35    Male  29.5         2     Non-Smoker
# 1           Emily Johnson   42  Female  26.8         2     Non-Smoker
# 2        Michael Williams   50    Male  31.2         3         Smoker
# 3             Sarah Brown   28  Female  22.3         1     Non-Smoker
# 4             David Jones   39    Male  28.1         2     Non-Smoker
# 5       Jennifer Martinez   45  Female  29.9         3     Non-Smoker
# 6         Daniel Anderson   33    Male  25.5         1     Non-Smoker
# 7          Jessica Wilson   37  Female  27.4         2         Smoker
# 8          Matthew Taylor   47    Male  33.0         3     Non-Smoker
# 9             Emma Garcia   31  Female  24.7         0     Non-Smoker
# 10  Christopher Rodriguez   40    Male  30.5         2     Non-Smoker
# 11       Olivia Hernandez   29  Female  23.9         1     Non-Smoker
# ...

# %%
#data Accessing!
#loc ==> columns name
#iloc ==> indexnumbers
health1.loc[2:7, 'mean']
# Out:
# 2    10565.0
# 3     5054.0
# 4     8839.5
# 5     9022.5
# 6     5776.5
# 7     8078.5
# Name: mean, dtype: float64

# %%
health1.iloc[2:7,1]
# Out:
# 2    50
# 3    28
# 4    39
# 5    45
# 6    33
# Name: Age, dtype: int64

# %%
df2 = pd.read_excel("/Healthcare-Insurance-Sample-Data2.xlsx")
df2
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN          Excel Sample Data        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN        NaN
# 2          NaN  Healthcare Insurance Data        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN        NaN
# 4          NaN                       Name        Age     Gender        BMI
# 5          NaN                 John Smith         35       Male       29.5
# 6          NaN              Emily Johnson         42     Female       26.8
# 7          NaN           Michael Williams         50       Male       31.2
# 8          NaN                Sarah Brown         28     Female       22.3
# 9          NaN                David Jones         39       Male       28.1
# 10         NaN          Jennifer Martinez         45     Female       29.9
# ...

# %%
df2.fillna(5,inplace = True)
df2
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          5.0          Excel Sample Data          5          5          5
# 1          5.0                          5          5          5          5
# 2          5.0  Healthcare Insurance Data          5          5          5
# 3          5.0                          5          5          5          5
# 4          5.0                       Name        Age     Gender        BMI
# 5          5.0                 John Smith         35       Male       29.5
# 6          5.0              Emily Johnson         42     Female       26.8
# 7          5.0           Michael Williams         50       Male       31.2
# 8          5.0                Sarah Brown         28     Female       22.3
# 9          5.0                David Jones         39       Male       28.1
# 10         5.0          Jennifer Martinez         45     Female       29.9
# ...

# %%
df2.drop_duplicates(inplace = True)
df2
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          5.0          Excel Sample Data          5          5          5
# 1          5.0                          5          5          5          5
# 2          5.0  Healthcare Insurance Data          5          5          5
# 4          5.0                       Name        Age     Gender        BMI
# 5          5.0                 John Smith         35       Male       29.5
# 6          5.0              Emily Johnson         42     Female       26.8
# 7          5.0           Michael Williams         50       Male       31.2
# 8          5.0                Sarah Brown         28     Female       22.3
# 9          5.0                David Jones         39       Male       28.1
# 10         5.0          Jennifer Martinez         45     Female       29.9
# 11         5.0            Daniel Anderson         33       Male       25.5
# ...

# %%
health1
# Out:
#                      Name  Age  Gender   BMI  Children Smoking Status  \
# 0              John Smith   35    Male  29.5         2     Non-Smoker
# 1           Emily Johnson   42  Female  26.8         2     Non-Smoker
# 2        Michael Williams   50    Male  31.2         3         Smoker
# 3             Sarah Brown   28  Female  22.3         1     Non-Smoker
# 4             David Jones   39    Male  28.1         2     Non-Smoker
# 5       Jennifer Martinez   45  Female  29.9         3     Non-Smoker
# 6         Daniel Anderson   33    Male  25.5         1     Non-Smoker
# 7          Jessica Wilson   37  Female  27.4         2         Smoker
# 8          Matthew Taylor   47    Male  33.0         3     Non-Smoker
# 9             Emma Garcia   31  Female  24.7         0     Non-Smoker
# 10  Christopher Rodriguez   40    Male  30.5         2     Non-Smoker
# 11       Olivia Hernandez   29  Female  23.9         1     Non-Smoker
# ...

# %%
health1[['Age','mean']].plot.line()
# Out:
# <Axes: >

# %%
health1.plot.line(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
#Creating Datafarme!
new = pd.DataFrame(columns = ['marks','names','pass','fail'])
new
# Out:
# Empty DataFrame
# Columns: [marks, names, pass, fail]
# Index: []

# %%
mark = [35,45,55,65,75]
name = ["kamal","naresh","raja","hari","mahesh"]
new['marks'] = mark
new['names'] = name

# %%
new
# Out:
#    marks   names pass fail
# 0     35   kamal  NaN  NaN
# 1     45  naresh  NaN  NaN
# 2     55    raja  NaN  NaN
# 3     65    hari  NaN  NaN
# 4     75  mahesh  NaN  NaN
